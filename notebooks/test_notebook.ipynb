# %%
import pandas as pd
import pandas
import numpy
import numpy as np
from sklearn.datasets import load_boston
from scipy.stats.stats import pearsonr, spearmanr

# %% [markdown]
# # Load test dataset

# %%
boston = load_boston()
X = pd.DataFrame(boston.data, columns=boston.feature_names)
y = boston.target

# %%
X
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 0     0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900   1.0  296.0
# 1     0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671   2.0  242.0
# 2     0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671   2.0  242.0
# 3     0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622   3.0  222.0
# 4     0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622   3.0  222.0
# 5     0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622   3.0  222.0
# 6     0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605   5.0  311.0
# 7     0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505   5.0  311.0
# 8     0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821   5.0  311.0
# 9     0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921   5.0  311.0
# 10    0.22489  12.5   7.87   0.0  0.524  6.377   94.3  6.3467   5.0  311.0
# ...

# %% [markdown]
# # Calculate mean correlation between variables

# %%
correlation_matrix = X.corr(method='spearman')

# %%
corr_list = list()
for i in range(len(X.columns)-1):    
    corr_list += np.abs(correlation_matrix.values[i, i+1:]).tolist()

# %%
np.mean(corr_list)
# Out:
# 0.4186358986029782

# %% [markdown]
# # Mean and Std from target

# %%
y.mean()
# Out:
# 22.532806324110677

# %%
y.std()
# Out:
# 9.188011545278203

# %% [markdown]
# # Correlation between features and targets

# %%
corr_list = list()
y = pd.Series(y)
for col in X.columns:
    corr_list += [abs(spearmanr(X[col], y).correlation)]
    
np.mean(corr_list)
# Out:
# 0.49301623665125105

# %%
max(corr_list)
# Out:
# 0.8529141394922163

# %%
X.apply(lambda x: abs(x.corr(y))).mean()
# Out:
# 0.4297209001821181

# %%
from sklearn.linear_model import LinearRegression

# %%
LinearRegression
# Out:
# sklearn.linear_model.base.LinearRegression

# %% [markdown]
# # Read a JSON file with Properties from OpenML

# %%
import pandas as pd
import json
with open('boston.json') as f:
    openml = json.loads(f.read())

# %%
qualities = openml['qualities']

# %%
properties = pd.DataFrame(qualities.items()).dropna()

# %%
properties.__len__()
# Out:
# 43

# %%
properties.to_csv('properties.csv')
properties
# Out:
#                                           0           1
# 0                         NumberOfInstances  506.000000
# 1                          NumberOfFeatures   14.000000
# 2                           NumberOfClasses    0.000000
# 3                     NumberOfMissingValues    0.000000
# 4        NumberOfInstancesWithMissingValues    0.000000
# 5                   NumberOfNumericFeatures   12.000000
# 6                  NumberOfSymbolicFeatures    2.000000
# 12                  MeanStdDevOfNumericAtts   29.016042
# 13           Quartile2KurtosisOfNumericAtts    0.490590
# 19              Quartile2MeansOfNumericAtts   12.008350
# 23                 MinKurtosisOfNumericAtts   -1.233540
# 27                 MaxKurtosisOfNumericAtts   37.130509
# 28                    MinMeansOfNumericAtts    0.554695
# 29           Quartile2SkewnessOfNumericAtts    0.699632
# 32                    MaxMeansOfNumericAtts  408.237154
# 34               PercentageOfBinaryFeatures    7.142857
# ...

# %%
API_KEY = '5d985b7484b1eb2a2a19bce849b07f0f'

# %%
import openml
from sklearn import impute, tree, pipeline
import openml
from sklearn import neighbors

openml.config.apikey = API_KEY

# This is done based on the dataset ID.
dataset = openml.datasets.get_dataset(531)

# Print a summary
print("This is dataset '%s', the target feature is '%s'" %
      (dataset.name, dataset.default_target_attribute))
print("URL: %s" % dataset.url)
print(dataset.description[:500])
# Out:
# This is dataset 'boston', the target feature is 'MEDV'
# URL: https://www.openml.org/data/v1/download/52643/boston.arff
# **Author**:
# **Source**: Unknown - Date unknown
# **Please cite**:
#
# The Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic
# prices and the demand for clean air', J. Environ. Economics & Management,
# vol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics
# ...', Wiley, 1980.   N.B. Various transformations are used in the table on
# pages 244-261 of the latter.
# Variables in order:
# CRIM     per capita crime rate by town
# ZN       proportion of residential land

# %%
X, y, cat, cols = dataset.get_data('MEDV')

# %%
dataset.

# %%
df.isnull().any()
# Out:
# 0    False
# 1    False
# 2    False
# dtype: bool

# %%
def timeseries_processing(window_size, series):
    # Write your code here
    average = sum(series) / len(series)

    result = []
    for l in range(len(series) - window_size):
        r = l + window_size
        print(r)
        moving_average = sum(series[l:r]) / window_size
        print(average - moving_average)
        result.append(average - moving_average)
    
    return average

# %%
timeseries_processing(2, [2, 4, 1, 2, 3, 4])
# Out:
# 2
# -0.3333333333333335
# 3
# 0.16666666666666652
# 4
# 1.1666666666666665
# 5
# 0.16666666666666652
# 2.6666666666666665

# %%
x = {1: 2, 3: 4, 4: 3, 2: 1, 0: 0}
sorted_x = sorted(x.items(), key=lambda kv: -kv[1])

# %%
sorted_x
# Out:
# [(3, 4), (4, 3), (1, 2), (2, 1), (0, 0)]

# %%
def months(dates, temps):
    # Write your code here
    month_temp = {}
    month_hottest = {}
    month_coldest = {}

    count = 0
    for date in dates:
        month = date[5:7]
        temp = temps[count]
        if month in month_temp:
            month_temp[month] += temp
        else:
            month_temp[month] = temp

        if month in month_hottest:
            month_hottest[month] = (temp if temp > month_hottest[month] else month_hottest[month])
        else:
            month_hottest[month] = temp

        if month in month_coldest:
            month_coldest[month] = (temp if temp < month_coldest[month] else month_coldest[month])
        else:
            month_coldest[month] = temp       

        count += 1

    sorted_month_temp = sorted(month_temp.items(), key=lambda kv: -kv[1])
    most_hot = sorted_month_temp[0][0]
    
    print(month_hottest.keys())
    print(month_coldest.keys())
    
    month_variance = {}
    for key, value in month_hottest.items():
        month_variance[key] = month_hottest[key] - month_coldest[key]

    sorted_month_variance = sorted(month_variance.items(), key=lambda kv: -kv[1])
    most_variante = sorted_month_variance[0][0]

    return int(most_hot), int(most_variante)

# %%
a = '2018-11-01'

# %%
a[5:7]
# Out:
# '11'

# %%
months(['2018-11-01', '2018-11-02'], [4, 7])
# Out:
# dict_keys(['11'])
# dict_keys(['11'])
# (11, 11)

# %%
a = {}

# %%
a['1'] is True
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-96-19ec3f893d0c> in <module>
# ----> 1 a['1'] is True
#
# KeyError: '1'

# %%
a = {'b': 0}

# %%
'b' in a
# Out:
# True

# %%
sorted(['b','ac'])
# Out:
# ['ac', 'b']

# %%
def label_encoder(x):
    # Write your code here
    terms = x

    for term in terms:
        if term not in terms:
            terms.append(term)

    sorted_terms = sorted(terms)
    
    unique_sorted_terms = []
    for term in sorted_terms:
        if term not in unique_sorted_terms:
            unique_sorted_terms.append(term)

    dict_terms = {}
    for i in range(len(unique_sorted_terms)):
        dict_terms[unique_sorted_terms[i]] = i
        
    def get_order(t):
        return dict_terms[t]

    return list(map(get_order, x))

# %%
label_encoder(['b', 'a', 'b', 'c'])
# Out:
# [1, 0, 1, 2]

# %%
from pathlib import Path
import os

# %%
p = Path(os.getcwd())

# %%
a = {'dataset': 'Boston', 'n_of_examples': 506, 'n_of_features': 13}

# %%
pd.DataFrame.from_dict(a, orient='index')
# Out:
#                     0
# dataset        Boston
# n_of_examples     506
# n_of_features      13

# %%
a = numpy.array([False])

# %%
((a==False) if len(a)>2 else a==False)
# Out:
# array([ True])
